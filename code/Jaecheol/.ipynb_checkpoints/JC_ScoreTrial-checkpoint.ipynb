# %%
train = pd.read_csv('../../data/train.hate.csv')
test = pd.read_csv('../../data/dev.hate.csv')

# %%
# 특수문자 제거
import re

def cleanse(text):
    pattern = re.compile(r'\s+')
    text = re.sub(pattern, ' ', text)
    text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z0-9]', ' ', text)
    return text

train['comments'] = train['comments'].apply(cleanse)

# %%
# 띄어쓰기
from pykospacing import spacing
train['comments'] = train['comments'].apply(spacing)

# %%
# 문장 분리
import kss
train['comments'] = train['comments'].apply(kss.split_sentences)
train['comments'] = [','.join(map(str, ls)) for ls in train['comments']]

# %%
# 중복 제거
from soynlp.normalizer import *
train['comments'] = [repeat_normalize(comment, num_repeats=2) for comment in train['comments']]

# %%
# konlpy
from konlpy.tag import Okt ; t=Okt()

words = []
for comment in train['comments']:
    # 문장 -> 토큰 분리
    sentence = t.nouns(comment)
    # 토큰 -> 한 문장으로 다시 합쳐서 저장
    words.append(' '.join([morph for morph in sentence]))
    # 품사 태깅
    #postagged.append(' '.join([morph.morphs.tag for morph in sentence]))

train['comments'] = words
train[200:250]
# Out:
#                                               comments      label
# 200                            염병 재산 천억 안내 머리 다가 꼬시 오지       none
# 201                                  옘병 프로그램 연애 따위 젠 안  offensive
# 202                                             과 이별 별       hate
# 203                           아빠 무슨 친가 뿌리 족보 제대로 걱정 구먼       hate
# 204                      남 탓 한국 사람 안 한국 평생 후진국 대표 예 재앙       hate
# 205                       개인 여행 걸 머 게 굳이 지금 시기 게 문제 거지  offensive
# 206                                        서로 거 충전 얼마나       none
# 207                                                 했짘       none
# 208                                                난 키  offensive
# 209                                        만 병원 스티커 발부  offensive
# 210                                                 진짜  offensive
# 211                                       재앙 이 제 박명수 테       hate
# 212                                       로마 안 거 부터 주작  offensive
# 213                                        시 선강 냐 왜 설리       hate
# 214      역시 화 방영 후 말 참고 미스터 션 샤 인도 화 이 해 안 간 말 분량 보고 말       none
# 215  오빠 나 이 제 스브스 아 내 친구 나 나 좀 도 뭐 거 너 너 친구 도 넌 이 제...  offensive
# 216                                         이형 번 두 명 좀       hate
# 217                                  작가 소설 연기자 연기 꼴 개꿀       none
# 218                첫 열애 기사 때 베뎃 전부 톡방 내용 글 애 쫄리겠 제발 선처       none
# 219                           하나 더 보통 저런 몸 임신 임신 차이 출산       hate
# 220                                        재미 지네 진흙탕 속       none
# 221                   살 살이 결혼 데니 김새론 입 누 영계 킬러 사촌형 후 전       hate
# 222                     가정 모습 사람 안 쇼 인도 부부 연기자 부부 연기 듯  offensive
# 223                       강 다니엘 빠순이 뭔가 저 리 맹목 실체 게 빠순이       hate
# 224                                                개꼬시  offensive
# 225                                    그냥 건 자기 끼리 훈훈거려       hate
# 226                                        사기 공소 시효 마당  offensive
# 227                                   드라마 노잼 좀비 퀄리티 무엇       none
# 228                             보기 방송 활동 얼굴 보고 밥 건 뭐 임  offensive
# 229                                            생각 걸 산다  offensive
# 230                                  저런 것 정신병 임 정신과 상담       hate
# 231                               젝키 계약 꼴 과 연 합류 이후 결말  offensive
# 232                                     츄 내 투어 정말 해 맑드       none
# 233                              한국 불체 태국 개 그 쉐리 일단 깜방       hate
# 234                               여자 또 우르르 여자 시작 진짜 과학  offensive
# 235                            축구 타이밍 겹 네이버 위 댓글 축구 배차  offensive
# 236                 머 결혼 안 그 염병 티비 거 결혼 안 헤어졋으 박 코미디 네  offensive
# 237                                     개그맨 올해 개그 중 최고       none
# 238  알 이 제 러브 라인 누구 김종국 민우 하자 광수 다시 러브 라인 줄 게 나 혼자 ...       none
# 239                                               정존 물       hate
# 240                                 티비조선 천사 퍼센트 퍼센트 혜자       none
# 241                                 현아 니 거 진짜 건 옷 표정 춤  offensive
# 242                                  욕 평생 욕 안 사 신분 별 게  offensive
# 243                                             사기꾼 자식  offensive
# 244                                           그 대통령 휴가  offensive
# 245                                           면허증 개 땄넼       hate
# 246                     앞 차 한서희 정신병 수도 말로 더러 븐 제발 상장폐지       hate
# 247                                          열폭 난리 진 짴  offensive
# 248                                               정말 짱       none
# 249                         남욕 전 늬들 집 구석 인성 뒤 댓글 전신 거울       hate

# %%
# Out:
# ['현재 호텔 주인 심정 난 하늘 날벼락 호텔 누 계속 추모',
#  '한국 미인 대표 분 곱 모습 그 모습 뒤 슬픔 처 알',
#  '남 고통 젠 처벌 래야 사회 대로',
#  '화 어설 펐는데 화 갈수록 데',
#  '사람 얼굴 손톱 것 인격 살해 동영상 몰카 메 생각',
#  '진짜 이 승기 비교',
#  '안 남녀 간 성 전쟁 한번 크게 치룬 후 일부다처제 여성 정치 참여 금지 여성 투표 삭제 세계 공통 문화 자리 잡 듯 암탉 댐',
#  '뒤 윤서인 재 평가 것임 게',
#  '재미 프로 왜 니 때문 폐지',
#  '방탄 팬 우리 방탄 성공 일단 방탄 부하 이름 기억 해',
#  '살 차이 부부 무슨 내용 긍금하',
#  '더 결혼 수기 여름 속',
#  '살 차이 요즘 세상 일도',
#  '얼마나 억울 꼬 만큼',
#  '아들 유모차 안타 데',
#  '살 차이 때 사고 딸 벌 능력 전현무 여자 전현 무 스타일',
#  '다이어트 필요 건강 위해 더 더 마르 봄',
#  '진짜 것 사랑 수 도저히 납득',
#  '정도 기럭지 애 의 심 의 구심 안 안 듬 비율 함',
#  '이하 호빗 한남 결혼 마셈 돈 연애 마셈 니 호빗 유전자 고통 네 후손 죄임',
#  '감량 박수 주지 그냥 거 디 자고 키 그냥',
#  '자유당 시절 하버드 로스쿨 입학 할리우드 진출 요',
#  '로 망 트리 거',
#  '연예',
#  '전인 둘 연남동 술집 술 거 이제야 기사',
#  '박 재미 이제 것 폐지 학부모 입장 폐지',
#  '진짜 뻔',
#  '눈 거 부 졸라 웃기 더 만',
#  '안',
#  '식 아침 점심 저녁 공복 유지 게 건강 더 듯',
#  '난 흐흐 한상진 연기',
#  '교도소 마취 자기 몸 거 커피 거만 거 보고 아랏는데 난 무 통증 무감각',
#  '로 안 시 청율 연기 이 거 때문 북 못',
#  '골빈 여자 이 기사 건 여자 투표 안 엠넷 사전투표 계집',
#  '여름 지영 스포츠카 타고 온 거 전',
#  '포도 밭 그 사나이 가운 연구원 정소영 솔 대한민국 여배우 중 최고 이 쁘 단아 급식 충 멋 윤아 아이유',
#  '홍보 시청률 자랑 남녀 주인공 비주 얼 남녀 주연 사극 말투 더빙 것 마냥 성우 시청률 그 모양 그',
#  '카톡 안 게 수집 땜 장씨 날벼락',
#  '사진',
#  '마마 승자 화사',
#  '이 거 영배',
#  '중 겨우 계약금 수준 사정 거 중립 기어 박아',
#  '연애 이 제 결혼 가정',
#  '이 부모 타고 이 젠 사람 얼마나 지난 화성 사건 피해 가족 그땐 가해자 시간 지난 오늘 피해자 수',
#  '열애 중 길',
#  '남자 비율 짓 덤벼 거',
#  '연애',
#  '살 차',
#  '주술 사랑',
#  '살 술 발랑 까졋 네 고딩 때 먹엇 듯',
#  '전이 한참 때 달 수도 아마 이십 초반 서로 때 콩 거 이 세상 성범죄자 인간',
#  '전이 달 수도 혈기 왕성 때 수도 듯 이제 일 말 사람 이해 혓재 살',
#  '최수종 결 서로 양보 배려 만 일 반 줄 아내 줌',
#  '',
#  '살 온갖 수단 동원 입대 연기 발 수 게 머 바질',
#  '녀 쿵쾅 쿵쾅 꿀꿀 꿀',
#  '서로 온몸 점 위치 알 듯',
#  '안 아치 통수 그동안 수 삶',
#  '박 뭐 기레기',
#  '차로 남자 집 왜 무조건 남자 탓 일',
#  '조리 고기 집 외식 가지 관심 병 더 감 니 다행 네',
#  '공익 꼴 진짜 모',
#  '아줌마 남 집 감 배',
#  '아줌마 고',
#  '여자 군대 안 군대 이야기 관심 젤 이야기 탑',
#  '여자 비율 가장 거 고소영 뻐 이유 여자 진심 한마디 여자 진심 여자 아예 안보 여요',
#  '여자 혜진 빙의 거 진짜 본인 인생 살기 여자 질투',
#  '살 이 청년 임 아저씨',
#  '살 시집 못 뭔가 문제 여자 건 모형 그냥 거르세 상대 필요',
#  '세 세로 잘못 거 정도 안이',
#  '세라 양세종',
#  '명 중 최종훈 이 제일',
#  '번 탈락 면 이제 술수 부리 티',
#  '어치 팔 만큼 파급 사람 왜 조롱 하나요 알 더 더욱 함부로 말 안',
#  '대로 가야 매 야노',
#  '아줌마 자식 피 씨방 엄마 방탄 동영상 처 보고 생각 경포대 문재인 지지 후',
#  '아줌마 댓글 비율 좀',
#  '여자 나이 값 못 현빈 하악하악 거리 거 개 혐 당신 뱃살 흉 측 얼굴 보고 반성 바람',
#  '이모 집중 살 초반 좀 캐스팅 좀',
#  '이',
#  '살 폐경 다리 노답 이',
#  '살 여자 로맨스 별로',
#  '세 이상 녀 임신 사실 쓸모 분리수거 대상',
#  '이 상관 애',
#  '걸 건 임 신',
#  '정상 애',
#  '빚진 것 그 빚 완전 인기 몇 년 게 더 홍진영 애 얼마 번',
#  '면 내 몸 무겐 데 난 소멸',
#  '살 출산',
#  '전 정준영 카톡 이 큰일 정말 누가 꼬리 짜르 기구',
#  '장윤정 껌값일 딸',
#  '도',
#  '면',
#  '',
#  '여자 강한나 테러 그 님들 보임',
#  '살 아빠 때 아빠 곽부성 축하',
#  '명 관계 거기 누구 말',
#  '무슨 피해 마냥 폭로 놈 안 매니저 놈 안습 인간 요즘 왜 신상털기 먼지 인생 낙인',
#  '면티 면 흠',
#  '의 아줌마 니 자식 말 하라 니 댓글 모음 자식',
#  '명 거가 지고 강 혼자',
#  '명 전부 론데 저 중 문희준 제일 인기 돈',
#  '전미선 박 일 성우 올해 몇 연예계 비보 거',
#  '여성 비율 능력 한국 남성 국제 결혼 답 일본 여자',
#  '초딩 캐릭터 김종민 어른 이미지 거 별로 안',
#  '김지영 못',
#  '김지영 왜 저런 쓰레기 영화 안 봄',
#  '일 이제 웨꺼 러시 사실 두 확인',
#  '살 딸 지금 주말 드라마 중 제일 양치 잠 나라 어린이 최수종 배우 죄송',
#  '대세 배우',
#  '여태껏 동거 거 요',
#  '그냥 눈 화장 색 거 뭐 거 톤 좀 거',
#  '급 가수 가수',
#  '천재 박명 수',
#  '아일랜드 이 홍기 쇼지 나머지 멤버 무 쓸모',
#  '팬 사람 정도 극성 데',
#  '좌빨 방송 여자 재앙 하나',
#  '드라마 기 대가 하나 적도',
#  '연습생 해',
#  '주말 은 번 꿀잼 노잼 것 황금 빛 이건 못 연기 발 연기',
#  '주말 드라마',
#  '이 영자 대상 준 게 이 해안 시 창률 그닥 차라리 이동국 주지 왜',
#  '전문가 란 직업 금융업 억 종사 저런 직업 처음',
#  '주말 드라마 다시',
#  '운동 무슨 죽 마녀사냥 운동 항해',
#  '필요',
#  '조개 개 태콩 개 조 징',
#  '모임 네 뉴스 못 뒷방 류 나라 것 친문 좌파 방송국 설립 아 퇴사 개 번 속 맘충 급 소신 나로 소명 다한 배현진 새삼',
#  '옆 침 걸 뇬들 무조건 남자 혐오 증 연예인 인기 라면 빤쯔 뇬들 얼마나',
#  '울 때 표정 안 듯',
#  '뉴스 연예 중계 연예인 기사 거',
#  '이 제',
#  '박 여기 생각 인생 항상 반전 무죄 이제 배우 활동',
#  '건 문제 걸 기사 게 문제',
#  '조선 연 보고 희트곡 하나 행사 비 훅',
#  '방송 저딴 식 표현 건 문제 생각 몰카 범죄 룰 우려 메세지 거 표현 방법 제 발 일 차원 생각 좀',
#  '의 인기 인지도 워 원 도 안 것 멤버 매력',
#  '한국 법 승리 놈 클럽 뭐 어쩌 관련 애 애 연예계 방송 퇴 출하 여자 연예인 인물 리도 내 추천 좀',
#  '제국 부활 빅뱅 컴백 방탄',
#  '올해 아이콘 빅뱅 위너 블핑 블핑 빌보드 날 네',
#  '안 이유 걸그룹 독보 톱 블랙 핑크 때문 흥 함',
#  '쉐키들 꼴 보기 이제 나와라 뉴스',
#  '걸그룹 가치 요즘 아이돌 살 거임 아이즈 장원영 안 유진 유나 애 살 존 나 여자 무조건 게 최고 임',
#  '급 기사 말',
#  '이제 개',
#  '짱',
#  '저걸 실제',
#  '페이크 러브 정말 실망 사람 방탄 팬 입장 만 일 신인 그룹 노래 과 연 수 뮤비',
#  '장난 서로 욕 하나 누가 입사 하나요',
#  '행진 아나운서 줄',
#  '박준형 이 기사',
#  '건 일단 의 심 함',
#  '구내 식당 진짜 모든 회사 중',
#  '니 개돼지 개 민국이 엉망 진창 주제 일베충 개 지인 베충 나라 문화 방송 말 쓰레기',
#  '요즘 일반 섭외 심',
#  '몽 욕 약 칭찬 반칙 메달 무슨 정당성 개 돼지',
#  '여성 중 가장 의욕 꿀 핑계 대기 일상 한국 여자 전 세계 선진국 여자 임금 문제 거론 게 가장 어이',
#  '로 열 애인 정해 거',
#  '무슨 천명훈 말 하차 요 천명훈 리 거 방송',
#  '은 진짜 또',
#  '조선',
#  '안마 제 이튠 주식 먹튀',
#  '고재 선생 줄 만',
#  '이사 저 사람 사람 일 수도 건 소속사 이미지 바닥 치 계속 여기저기 기사 건 기분 탓 걸 건 별로 임',
#  '음악 케이팝 음악 음악',
#  '내 나이 쉰 네 살 순간 순간 기억 때 나 혼자 몸 때 배우 느낌 요',
#  '전혀 보이지 설리 잘못 것',
#  '그 성별 산이 향 피 쉴드 오지',
#  '노무현 게 다행 요',
#  '꼰대들 특징 나 때 말 누가 참고 버티고 일로 원래 사회 생활',
#  '홍상수 김민희 진짜 사랑 거',
#  '속 보 국민 가수 조용필 도 빨갱이 마 조용필 거 고향이 데 고 전라도 아이 카이',
#  '정용화 오빠 죄인 김연아 박지성 죄인 오빠 군대',
#  '기사 윤 총경 승리 전라도 동향 서로 술 골프 승리 외 운영 술집 영업정지 외 계속 분리 절',
#  '반성 거 그냥',
#  '시즌 사람 아무',
#  '충격 하나 경이 강 비 안',
#  '사 게 이 게 기사 니',
#  '경원 미모 실화',
#  '약',
#  '관종',
#  '약 슬슬 기어',
#  '핵폭발',
#  '메 제목 거',
#  '저런 거지 알 꼰대 키 말',
#  '게 자랑 로 그것',
#  '언제',
#  '궁합 안',
#  '한남 말 무시 요 우리 팜므파탈 나래',
#  '성과 비교 안 자연미 거의 이 영애 배우 급 미모',
#  '씨뱅 마약 것 성추행 것 무안 줫다 존 여자 연예인 감히 생글 거리 기사 헤드라인 비꼬기 시전',
#  '맴버 중 명 법 데 무슨 거',
#  '여자',
#  '상관 비호감 건',
#  '직 폐지 안',
#  '아즘마 살 왜 자꾸 기 어나 돈 예능 깝 치더 진심 관종임',
#  '정보 부 조사 하나 승리 곧 자살 경찰 질소 자살',
#  '라인',
#  '작위 느낌',
#  '사기 절도 깜방 하루 게 인간 본성 죄 사람',
#  '염병 재산 천억 안내 머리 다가 꼬시 오지',
#  '옘병 프로그램 연애 따위 젠 안',
#  '과 이별 별',
#  '아빠 무슨 친가 뿌리 족보 제대로 걱정 구먼',
#  '남 탓 한국 사람 안 한국 평생 후진국 대표 예 재앙',
#  '개인 여행 걸 머 게 굳이 지금 시기 게 문제 거지',
#  '서로 거 충전 얼마나',
#  '했짘',
#  '난 키',
#  '만 병원 스티커 발부',
#  '진짜',
#  '재앙 이 제 박명수 테',
#  '로마 안 거 부터 주작',
#  '시 선강 냐 왜 설리',
#  '역시 화 방영 후 말 참고 미스터 션 샤 인도 화 이 해 안 간 말 분량 보고 말',
#  '오빠 나 이 제 스브스 아 내 친구 나 나 좀 도 뭐 거 너 너 친구 도 넌 이 제 신입 누구 스타',
#  '이형 번 두 명 좀',
#  '작가 소설 연기자 연기 꼴 개꿀',
#  '첫 열애 기사 때 베뎃 전부 톡방 내용 글 애 쫄리겠 제발 선처',
#  '하나 더 보통 저런 몸 임신 임신 차이 출산',
#  '재미 지네 진흙탕 속',
#  '살 살이 결혼 데니 김새론 입 누 영계 킬러 사촌형 후 전',
#  '가정 모습 사람 안 쇼 인도 부부 연기자 부부 연기 듯',
#  '강 다니엘 빠순이 뭔가 저 리 맹목 실체 게 빠순이',
#  '개꼬시',
#  '그냥 건 자기 끼리 훈훈거려',
#  '사기 공소 시효 마당',
#  '드라마 노잼 좀비 퀄리티 무엇',
#  '보기 방송 활동 얼굴 보고 밥 건 뭐 임',
#  '생각 걸 산다',
#  '저런 것 정신병 임 정신과 상담',
#  '젝키 계약 꼴 과 연 합류 이후 결말',
#  '츄 내 투어 정말 해 맑드',
#  '한국 불체 태국 개 그 쉐리 일단 깜방',
#  '여자 또 우르르 여자 시작 진짜 과학',
#  '축구 타이밍 겹 네이버 위 댓글 축구 배차',
#  '머 결혼 안 그 염병 티비 거 결혼 안 헤어졋으 박 코미디 네',
#  '개그맨 올해 개그 중 최고',
#  '알 이 제 러브 라인 누구 김종국 민우 하자 광수 다시 러브 라인 줄 게 나 혼자 산 전 현무 혜진 처럼 다시',
#  '정존 물',
#  '티비조선 천사 퍼센트 퍼센트 혜자',
#  '현아 니 거 진짜 건 옷 표정 춤',
#  '욕 평생 욕 안 사 신분 별 게',
#  '사기꾼 자식',
#  '그 대통령 휴가',
#  '면허증 개 땄넼',
#  '앞 차 한서희 정신병 수도 말로 더러 븐 제발 상장폐지',
#  '열폭 난리 진 짴',
#  '정말 짱',
#  '남욕 전 늬들 집 구석 인성 뒤 댓글 전신 거울',
#  '애초 여 자 왜 욕 성 상품화 때문 저 기 사 댓글 남새 기 성희롱 그 스 레기짓 안 해도 성 상품 욕 한남 때문 욕 건 성희롱 오지',
#  '마 서빙 누가 하노 퍼뜩 온',
#  '핫 핫 기사 악플 달러',
#  '게이 줄 옷 화장 좀 봨',
#  '막 거지',
#  '또 기 사 네 법적 대응',
#  '뭐 딸 인연 김치 녀 진짜 별 거 가지 욕 세계 원정 성매매 위 김치 녀',
#  '재미 사람 인생 조지 려 햇 거 내 법 이 벌금 맥 고 끝내 재미 남 인생 조지 려 햇던 저 인생 새',
#  '차예련 악플 연예인 난 도 차예련 못 네 글 타고 사과 건더기 그냥 이해 아줌마 건 안 그냥 좀',
#  '차유람 세뇌 예수',
#  '돈 뭐 만하 기어 연기 또 니 상황 그냥 또 고 이순재 배우 너 그 식 이 쁜 척 졸라 해대 면서 책임감 년',
#  '드라마 단막극 정도 그냥 이 승기',
#  '복면 왕 레전드 여자 왕 소향',
#  '연예 이미지 관리 시작',
#  '원래 돈 능력 여자 여럿 끼 건 니 쿵쾅 거기',
#  '원래 이레 쿵쾅 네 원래 빻 앗 살 빻',
#  '위스플 제외 생 개 소리',
#  '그 진짜 정신 병자',
#  '거 질투 무슨',
#  '곧 흑역사 취급 명단 네 이 진행 중인 작자',
#  '댓글 사재기 햇 님들 확증 뜰 좀 어디 당신 심증 일 뿐',
#  '사람 댓글 요새 호의 적 바로 사진',
#  '뇬 네 호텔 방 뇬',
#  '잼',
#  '농구 간다',
#  '그 여 자랑 알렉스 바지 커서 바느질 바지 보풀 이나 난리',
#  '힐링',
#  '전현무 작업',
#  '아들 죄 상관 아들 의도 합의 일 왜 해',
#  '장태준 거 시즌 이유 적폐 급수 장태준 최정 적폐 송희섭 적폐 이 엘리야 정의 척 적폐 호구 레벨 이 성민 의원 강 의원 보좌 관 한도 경 정도 호구',
#  '복귀 다 안 복귀 이 중성',
#  '난민 별 룬데 윤서인 좀 해',
#  '오늘 댓글 왜 댓글 부대 말투 도리어 박나래 역효과 일',
#  '현석 너 아치 근성 못',
#  '문 대통령 대책 강 계시 중국 지원 우리 국민 안심 수',
#  '신부 옆 다른 이미지 축하 울 집 시어머니 보시 안 것 우리 아주 버 장가 가라 다시 말씀 듯',
#  '승리',
#  '노래 짱 언니 완전 팬 꼭 쾌차 다시 무대',
#  '둘 결혼',
#  '박일성 우님 더빙 영화 거나 마찬가지 목소리 고인 명복',
#  '가로세로 독자 구독 정도 것 디',
#  '스엠 머리 채 뱔 언플 안 지금 개',
#  '여자 성별 연예인 임 여자 만날 수 성별 인 남자 권력 관계 여자 남자 고생 여성 우월 주의 국가',
#  '가면 왕',
#  '자녀 하치',
#  '가부장제 도태 답',
#  '가사노동 비 매일 배달 일 당 오우야',
#  '가세 연 김태호 재산 해명 좀 월급 걸 분양 연 분석 왜 반응',
#  '가수 대마 좀 해도 맨 정신 곡 못',
#  '가수 은퇴 햇 몇 년 지나 애 명 음반 콘서트 엔터테이먼트 회사 사람 문희준 왜 못 것 것 뭘 보기 안 돼지',
#  '가슴 연기 정말 부디 소서',
#  '가슴 뭐 때',
#  '가시 나들이 무조건 사랑 결혼 이혼 지름길',
#  '가시 나들이 여자 가해자 입 닥치 진짜 못',
#  '가식 덩어리 팬 것',
#  '가식 맙시 만약 당신 앞 마닷 남자 다가 당신 빤스 안 자신 진짜 하트 날 릴 땐 언제 이제 비난 여자 진짜 못 보임',
#  '가식 메뚜기 빼 박 팩트',
#  '가요 무대 승자 최 기간 시청률 보증',
#  '가운데 사람 누구 군인 립스틱 건가',
#  '임기 여자 다이어트 집착 이유 임신 걸 남자에게 위해 임신 여자 유혹 남자',
#  '장미여관',
#  '가장 애가 세상 구한 모티브',
#  '가정 요리 배우 고 살 듯',
#  '가족',
#  '가족 인물',
#  '가족 예능 중 최악 아들 재기 위해 가족 연예인 병 것 네 프로그램',
#  '가족 도의 적 책임 전 국민 실망 빠트린 피의자 와이프 그 드라마 방송 고 집 를 보이콧 하나요',
#  '가지 별거 걸 왜',
#  '각 시 예전 구설 수 풋 여기 게',
#  '간만 좀 전 회장 빈 자리 전 회장 땐 의자 토크 해도',
#  '간만 번 보기 채널 돌림 왜 풍상 씨 수목 이 걸루',
#  '간통죄 폐지 고로 법적 홍상수 김민희 건 결격 사유 한번 인생 사랑 사람 자식 의 무감 부인 살 필요 난 홍상수 이해',
#  '사람 게 이치 고인 명복',
#  '수도 거 못 가게 출국 걸 걱정',
#  '갈수록 군대 복무 기간 줄 개월 갓 온 거 스 브 얼',
#  '갈수록 노잼',
#  '갈수록',
#  '갈수록 자꾸 섭 외력 거 박근혜 이명박 출연 왕 해',
#  '갈수록 싸구려 네',
#  '갈수록 재미',
#  '갈수록 종답',
#  '갈수록 호감',
#  '감당 천도 현재 돈 도끼 해도 변상 못 그냥 때 앨범 보답',
#  '감량 게 거 방송 누구',
#  '일 복귀',
#  '감우성 연기 완전 박 초딩 아들 최',
#  '갑 동정 여론 뭐 전 국민 기만 놈',
#  '갑상선 항진 증 눈 튀어 거 거 그 병 얼굴 고 걸 테 눈 성형',
#  '갑자기 뇌출혈 아버지 슬픔 동안 울 함 저 이 프로그램 아버지 보고 나 연 어머니',
#  '갑자기 쇼 때 일리네어 조만간 일 그 예언 적중 박자',
#  '감정 방법 사이비 교주 방법 절대 행복 불행 면 건 이상윤 전씨',
#  '골로 신 연예',
#  '갓 정아 좀 데 연기 이면 여기저기 배우 갓 바 말',
#  '강가 빛 시 후 인생 미투 운동 동참 고해 후 전자발찌 차야',
#  '강가 빛 인생 시 후 미투 고백 해 고해 다음 셀프 전자발찌 가즈',
#  '강간 모 자살 안 거 진짜',
#  '강경헌 데 나와라 연수 안 살 맛 안',
#  '강기영 공효진 맛녀 점차 영화 드라마 홍보 게스트 망조',
#  '강남 챙녀 앗',
#  '강남 유 이 더',
#  '강남 애 거 개 사람 듯 좀',
#  '강남 정글 목적 먼지 알 것',
#  '강남 왜 거짓말',
#  '강남 임 불구 인정 거임 이승기 정준영 친구 날라리 용서 안해',
#  '강 다니엘 개 데',
#  '강 다니엘 명절 때 못 꼭 다시',
#  '강 다니엘 노력 거 안 속 얘기 진심 사람 알 여기 얘기 사람 중 정말 팬 사람 얼마나 어차피 자기 일 말 것일 뿐',
#  '강 다니엘 머리 채 꼴 보 넼 순위 걸 온갖 그로 당',
#  '강 다니엘 팬 생각 초 스피드 거 앞',
#  '강 다니엘 팬 억지로 터트린 듯 장나라 아이돌 뉴스 만 파급',
#  '강 다니엘 응원 합닏',
#  '강 다니엘 좀',
#  '강단 딸 딸 외국 보 연애 질',
#  '강대 니엘 박지훈 웅 성우 강대 니엘 국민 알',
#  '강동 주도 거',
#  '강변 즐 티비 얼굴',
#  '강변 생각 훨 씬 질',
#  '강성훈 자살 거 기 분 꼭 건강 추스려 다시 모습 응원',
#  '강수지',
#  '강수지 옷 흰색 기자',
#  '강씨 갈수록 입 햇님 먹방',
#  '강용석 가로 세로 연구소 한효주 고 언급',
#  '강원래 이제 가보 네',
#  '강은비 팬 증거 하나 경 잘못',
#  '강인 거지 마녀사냥 치면 정준영 톡방 모든 사람 조사 대상 프로그램 뭐 단발 톡방 두',
#  '강인 축구 줄',
#  '강지환 팬 감금 핸드폰 남자 집 왜 술 또 뭐 거지',
#  '강철 비 라면 신 정도 거',
#  '강철 비 잼 데',
#  '강타 실제 보넹 개 취지 뭐',
#  '강타 영웅재중 탑 방탄 동해 이 특 시원 애 비쥬 얼',
#  '짱 냄새',
#  '나 기사 게 거의',
#  '나 한지민 투샷 안 게 듯 한지민',
#  '강혁 민 필요 왜 과거 친 동료 그때 좀 낌새 이 상해 멀리 몇 년 후 알 상황 여러 사람 그때 심증 이 말 것 뿐',
#  '강현석 친구 거 하나',
#  '강형우 캍 사람 정이 보이 저런 사람 칼 정말 냉정 하단',
#  '강호동 이수근 조합 예능 뭔가',
#  '강호동 도 이제 실타',
#  '강효진 기자 공익 제보자 신분 노출 공익 신고 보호 법 제 제 항 처벌 대상',
#  '',
#  '남자 연예인 군대 문제 욕 미투 무조건 연예인 응원',
#  '남자 내 쪽 리다',
#  '팀 좀 메인 싱어 건 젝키 팬 입장',
#  '여자 존 나 건가',
#  '사기 성희롱 욕 여자 남자 여자 사기 게 능력 남자 수지',
#  '합의 나잇 구서 나중 성폭행 주장 사례 어디 둘입 검증 통해 진위 여부 다음 욕',
#  '개 종족 애 욕 괜 수지 물 지졍',
#  '개 니',
#  '개 새 끼 살 장난 것 음식 가지 장난 좀 말',
#  '개강 주말 평일 것 해도',
#  '개 새 끼',
#  '개 거품 노래 전혀 못 음악 자꾸 손 이름 것 라스 덕',
#  '개그맨 김경민 나 느낌',
#  '개그맨 몸 왜',
#  '개그 가스 내 중 천이슬 가장 쁘 천이슬 매 이 쁘노 가스 내 스랍',
#  '개그 프로 활용 것 열심 열정 박수 당 배우 김 욤 화이팅',
#  '개 소나 국민 청원',
#  '개 노잼 프로그램',
#  '개 노잼 철거 촌 주 무대 배경 임 미션 임마 블 훠 얼씬 거 보고 보 눈 느낌',
#  '개독 개종 약속 결혼 하나',
#  '개돼지 네티즌 무었 진실인 편 내 편이 거지 음식 이념 붙이 비판 진짜 부류',
#  '개돼지 민국 또',
#  '개돼지 집단 개 한민족 실상 사촌 땅 사면 배 민족 앞 선 뒤 호 박씨 게 일 상임 소름 개 민족',
#  '개돼지 특 일본 기업 유니클로 일본 맥주 등 등 불매 스파이더맨 트와이스 소비',
#  '개 남자 프로게이머',
#  '개 고양이 애 정상인 애',
#  '개 망나니 또 결혼 재앙 재앙',
#  '개복 어도 장가',
#  '개뻥 자 고 얼굴 화장 거 정리 정돈 얼굴 구먼',
#  '개성 도 무 매력 소유자 남자 안 짐 돈',
#  '진짜 라디오 놈 문제',
#  '개 낌 갑자기 기안 답글 왜 갑자기 졋 네 역시 네이버',
#  '김',
#  '개인 면접 왜 비리 거 실제 교수 개인 면담 일반인',
#  '개인 최고 커리어 올림픽 종합 현 학원 강사 피겨 전설',
#  '개인 취향 시청 재미',
#  '개인 거',
#  '개인 눈물 씬 윤 세리 서단 음',
#  '개인정보 도용 그 음원 팀 대국민 사과 래야 건 실수 하여튼',
#  '개존잼임 이 거 꼭',
#  '개 네 혜진 언제 혜진 불륜 드라마 안',
#  '개 꼴 보기 게 사람 마음 얘 광고 수익 번 게 얼굴 돈 고 관리 금술 수 사람 거임 이 쁘 관리 안 상대 쪽',
#  '개콘 장대 장도 연 캐릭터 안나 씨',
#  '개티즌들 또 소설 그 난리 법석 친 김광석 마누라 사건 무혐의',
#  '개티즌들 마녀사냥',
#  '개판 네 김준호 디엔에이 도박 듯 차태현 실망 틀 프로 폐지',
#  '개폭망 벌써 차트 아웃 따리',
#  '갠',
#  '갠 스타일 스카이 캐슬 지적 스타일 듯 이건 술집 여자',
#  '갠 성 연결',
#  '주말 보기 돈 정도',
#  '다시',
#  '죽 존경 무 모',
#  '해 뭘 돈 월 사장 똥꼬 것',
#  '이병헌 감정 때문 빼액 거지 연기 여기 댓글 말 강 동원 김남길 상대 이병헌 사생활 연기 송강호 김윤석 노 급',
#  '결혼 노총각 노처녀 결혼 게 뭐 자랑 건 모 성격 이벤트 눈요기 될런',
#  '티비 인터넷 안 서로 얼굴 맙시',
#  '너 이제 관심',
#  '폐지 요즘 무한도전 노잼',
#  '하차 리얼 노잼',
#  '거 담배 좀 피시',
#  '거 예비 며느리 빚 청산 주구 시 부모 이 쁨 좀',
#  '거거 남자 사업 접대 수 것 비즈니스',
#  '거기 박씨 빼 신혜선 박씨 밥상 숟가락 하나 온 뻔 도둑',
#  '거기 조사 게 언론 노출 덜 묘',
#  '거부권 삥',
#  '거의 대부분 사람 양준 일 아무 관심 거지 자꾸 이 제 거부 감',
#  '거참 노친 때 거 가지 실검 장악',
#  '거참 수도 요즘 애 진짜 적 뭐 큰일 저 난리 별 것',
#  '다이어트 더 보기 듯합 당 심 복면 왕 한번 더 출연 아무 못 듯',
#  '건 블리 시청 의미',
#  '건',
#  '건모 일상 옷 머리 스타일 해 삐 갇 우수 운 컨셉 우수 꽝 런 복장 신부 의도 조',
#  '건 모도 악플 때 매 듯',
#  '건축학 개론 지금 다시 건축학 개론 건축학 개론 맙시 볼 때 가슴 애려',
#  '걸그룹 생명 이 제 애 거 이 제 젖 타령 가지',
#  '걸그룹 애 더 이 쁘',
#  '걸',
#  '메퉤 년 안',
#  '걸 복 동이',
#  '걸 크러쉬 이 거 킬로 이 정작 그 연예인 마이너스 일 뿐',
#  '검사 때 방울 마약 누구 거',
#  '검색어 조작 지금 코로나 때문 난리 보도 못 검색어 이번 정부 조작 정부',
#  '사제 영화 백만 이 영화 천만이 게 줄',
#  '머리 외국인 혐 이 나라',
#  '검찰 개혁 꼭 해',
#  '검찰 발 부 법원 실질 심사 판사 발부 거지 경찰 신청 거 검사 판단 법원 신청 검사 발부 게 어딧 니',
#  '검찰 조사해 완전',
#  '동안 이 네',
#  '반전 난 랄 롤',
#  '이 쁘긴',
#  '겁 여자애 하나 여러 명 서바이벌 온 비 아이 진심 정신 미숙 사람 마약 접근 저런 사람',
#  '겉 속 졋겟',
#  '게리 두 명 네',
#  '게스트 서우 명 정도 박보영',
#  '게스트 별로 차태현 땜 볼 듯',
#  '게이',
#  '게임기 저작권 불법 인 건 알',
#  '겨울 불우 이웃 돕기 건 다른 나라 다른 일만 온 사람 노력 고생 그냥 방송 로또 몇 일 안 냄비 두 번 상처 줄 것',
#  '견찰 실명 오픈 조건 뭐 필로폰 투약 면서 할리 홀랑 견찰',
#  '결과 때 신동욱 편도 조 부편 안 듯 사실 연예인 통 수치 걸 종종 지금 말 좀 더 땐 거',
#  '구걸 앨범 소리',
#  '남자 건 뇨쟈들 요즘 여자 순결 남자 올인 여자 나잇 세상 여자 니 남편 때 아다라 시 나',
#  '세계 인정 건 일베 나 부랭이 봉준 호 송강호 김연아 방탄소년단 소위 니 말 좌파 자신 사상 세계 기준 뒤 처지 걸 좀 깨',
#  '승자 핑 빠돌이 대가리 박아',
#  '유연석 커피 프렌즈 사기',
#  '준영 다솜 바람 피 무인도 표 자연인 나 자연인 출연',
#  '쥬비스 광고 글',
#  '합의 해체 합의 상황 소송 거 건 무슨',
#  '',
#  '양세종 장혁 둘 중 하 둘 뭐 이성계 쪽 역사 못',
#  '은 주말 시간대 프로 역시 스브스 평일 시간대 프로 돌파 김 사부 최고 네 김 사부 초 중반 프로 돌파 중 김 사부 한석규 대상 확정',
#  '결론',
#  '결론 빠순이 문제 거',
#  '결백 당신 안 어울림 그냥 자백 반성 척 해',
#  '결별 관심 그냥 혜진 왜 화사 차라리 백 번 보이',
#  '결 식 꼭 축하',
#  '결혼 가즈 겉 껍데기 외모 돈 사람 이 세상 마음 성격 보고 사람 선택 줄 눈 아씨',
#  '결혼',
#  '결혼 놈 댓글',
#  '결혼 듯 보기',
#  '결혼 축하',
#  '결혼 생각 집 방',
#  '결혼 듯 연애 여자 나',
#  '결혼 안 뭐 짓',
#  '결혼 사기 피임 애 거지 여자 임신 인생 애죽 양육비 주기 저런 피임 하든 애가 지면',
#  '결혼 상대 송지효 홍진영 일단 송지효 좀 보이 홍진영 행사 영상 성격 그대로 어른 틈 거 론 밤 말 다한',
#  '결혼식 준비 중 임신 자기 입 갑작스레 결혼 발표 거 약간 냄새 일단 결혼 임신 축하 조금 더',
#  '결혼식장 술 집 걸 명 신부 번 입장 술집 명과 술 건 사실 화장실 경찰 조사 좀',
#  '결혼 안 혼자 게 애 뭔가 요 성욕 해결 하나 묘 유흥업소 란 얘',
#  '결혼 알베 남자',
#  '결혼 인륜 지대 사라 만큼 일 애 소꿉 장난 참으로 이',
#  '결혼 부인 집 촬영 외박 쇼 축하',
#  '결혼 인 기 급 하락 왜',
#  '결혼 증가 그것 임신 정나미 게다가 상장 폐기 녀',
#  '결혼 유부 남 빠순이 진심 노답 역시 빠순이 화',
#  '결혼 놈 전 여자친구 연락 나 보지',
#  '결혼 데 자기 연예인 고 악플 수준 사람',
#  '결혼 어차피 소시',
#  '결혼 더 거 친구 시간 거',
#  '결혼 백치 여자',
#  '결혼 여자 애 요즘 여자 무슨 생각 결혼 남자 등 꼴 생각',
#  '고사 백종원 과 또 유재석 그릇 차이 확 진짜 대상 누가 이견 백종원 생각',
#  '경규 옹이 저 맥락 비교 대상 차 은우 건 차 은우 대표 미남 생각 방증',
#  '경규 최고 시청률',
#  '녀 게 겨우 출판사 연애 남자 회사 생활 안',
#  '림 좀',
#  '전 여친 이 방송 일 분',
#  '경준 와이프 말 안 좀 패',
#  '경찰 것 마약 검사 블랙 핑크 마약 검사 냄새',
#  '경허 일도 열심 요리 흥 허니 허니',
#  '이 왜 안',
#  '계속 거 이 인간 인성 거지',
#  '계속 이해 거임',
#  '계속 요가 연기',
#  '계속 제 맛 크게 넌 일반인 싸구려 기성복 게 비지 떡',
#  '계속 광대뼈 조커',
#  '계약 기간 남아 건 패일 수도',
#  '계집 댓글 누가 개 소리 여자 왜 겨 여자 종특',
#  '계집 대체로 기적 더',
#  '계집 여름 브라자 대신 꼭지 접착 테이프 붙이',
#  '계집 새끼 덜 젖 젖 계집 새끼 나이 저 나이 상폐 임신 불구 년',
#  '계집 어차피 사 내의 손 것 사 내 계집 질도 거지 계집 년 명 때문 대한민국 영화계 거물 하나 또',
#  '고 김주혁 때 김주혁 기사 인터넷 도 배 그 엑소 개집 아마',
#  '고집 보이 똑 보임',
#  '고딩 때 처 거 살 기억 정도 진성 듯 처 데 이유',
#  '럼 럼 거지',
#  '마 느낌 네',
#  '고마 좀 사람',
#  '처리',
#  '고모',
#  '고백 부부 시즌',
#  '고백 듯',
#  '고소 고발 난무 머 자랑',
#  '고소영 임 류 아우라 듯 김태희 전 지현 하지원 수지 일반인 화 저 사진 제 니 왼쪽 애가 더',
#  '고소 회수 수 금액 불구 고소 채무자 손발 잘못 건 사실 공개 이면 이해 관계',
#  '고승 변호사 놈 저런 취급',
#  '고승 변호사 외모 태도',
#  '고양이 건 게 왜 얘 잘못 임 애 다시 데 왜',
#  '고영욱 옴 촤 하하',
#  '우시 상폐 질투 만하',
#  '원희 작년 연말 시상식 때 선배 때 다른 연기자 혼자 자리 거 보고 개념 버릇',
#  '고음 사람 노래 거 이석훈 듣기 목소리 노래 장르 뿐 불 후 선 이석훈 목소리 안 먹혓 거 첨 고음 점수 나왓거 지금 달라',
#  '고 이은주 배우 서로 사랑 때 다른 모습',
#  '고인 팔이 진짜 세상 지능 애',
#  '고정관념 생각 내 만큼 상위 퍼 산다 거 한혜진 정도 이제 건',
#  '고주원 커플 방송',
#  '고주원 표현 진심 젤 연기자 연기 진심 신 중하 배려 정말',
#  '고지용 왜 자꾸',
#  '고층 아파트 살 층 반 지하',
#  '고현정 배 행동 거지 돈 것 맘 안 무뢰한 짓 거지 뭐 가끔 얼굴 드라마 문 문 등장 그냥 동남아 얼굴 게 방송 탈',
#  '고현정 이 혼',
#  '고현정 특 미실 이후 뭐 하나 제대로 게',
#  '고현정 카리스마',
#  '곧 너 왜',
#  '곧 연예 기사 댓글 폐지 하니 아줌마 댓글 볼날 얼마 안',
#  '곧 이 혼 뉴스',
#  '골목 식당 폐지',
#  '골목 식당 피디 경찰 조사 번',
#  '골키퍼 골 안 자 핑 끝 국민 응원',
#  '골프 친 게 남편 사건 공모 증거 뭐 왜 별 비난',
#  '골프대회 중 무단 이탈 무 개념 것 개인 전도 팀 경기',
#  '골프 선수',
#  '골프 예능 정말 신 요새 방송 콘텐츠 것 볼 게 진 것 골프 다른 스포츠 비 이번 기회 통해 알 수 것',
#  '도 거 원희 분 엄마 요 끝 시간 바 요',
#  '공개 하나 기자 단독 타이틀 기사 내 기자 기자 기자 걱정',
#  '공과 사 어쩌 저쩌 거리 애 중딩 연애 일 집중 게 얼마나 오히려 현아 연애 자기 무대 더 프로 다운 모습 연애',
#  '놀이 게 뭐 벼슬 김치 남 한남 즈그 끼리 빨 아대 거',
#  '공부 공부 민가',
#  '공부 설치',
#  '공블리 항상 응원 배우 인성 저희 팬 매너 갑',
#  '공산당 교육 밑 자랏우 공산당 말 한국말 신들 너',
#  '공산당 무서움 중국 이 정도 북한 미국 박정희 우리나라 꼴일 수도 걸',
#  '공연 보지 맙시',
#  '공유 씨 허겁지겁 거 보고 소름 협박 거 당근',
#  '공인 이란 것 졸 청념 척 이혼 오지 조상 피 눈물',
#  '공인 이면 모범 좀 쓰레기',
#  '공장 진짜 알 내심 걱정',
#  '공정위 백 대표 방송사 무슨 관계 프랜 사장 땅 헤엄 치 전국 다방 순식간 기존 커피숍',
#  '공효진 바가지 쇼핑몰',
#  '공효진 발 연기 이질 생각 읍 던데 왜 계속 연일',
#  '공효진 대상 축하',
#  '공효진 김래원 다른 예능 안 시청률 도 안 저런 프로 원아 차라리 시상식 나와라',
#  '과거 마지막 승부 농구 손지창 주인공 박형준 정말 당시 중대 동호회 농구',
#  '과거 과거 마음 안 고조 배',
#  '과거 과거 일 뿐 노래',
#  '과거 미화 오지 천재 서태지 극찬 노래 못 게 팩트',
#  '과고 서울대 카이스트 가기',
#  '과연 신동욱 과거 재기 이 시기 기사 행동 진실 일이 조부 언론 플레이 손자 망치 건 나 생각',
#  '과연 명일 옹 강 근본 어디 못 간',
#  '과 설정 여기 즐 나바',
#  '과 일본 정부 잘못 원폭 죄 민간인 잘못 이 얼마나 행위 인 지하 게 더',
#  '관리 좀 하자 저건 현상 관리 수 나이 중 남 배우 저 뭐 여배우 기자 후덕 제목 진심 숙연',
#  '관상 과학 거 알',
#  '관상학 앞 빵 제 집 들락날락 상이 구나',
#  '관심 선동 질 불과 함 호응 건 바보 짓',
#  '관심 기사',
#  '관심 문씨 아저씨 일자리 언제 관심',
#  '관심 지상파 욕 더',
#  '관심 종자 연예인 병',
#  '관 종도 관 종이 노답',
#  '관 종이 네 실수 걸 과 격하 짜증 거 보기 승질 듯 애 벽 똥 때 살 인간 데 엄마 말 애 엄마 전 전남 친일 죽 여자',
#  '관 종인 건',
#  '관종 짓 또 시작 남친',
#  '광고 재 네 가격 소리',
#  '광규 형님 국 이형 팬 꼭 좀 전',
#  '광대 철 가면 아줌마 개 소나 솔로',
#  '광수 티아라 화영 효영 아름 둘 피해자',
#  '광수 노리개 것 마음 좀',
#  '광희 의 외로 추 격전 면모 에이스 이 거',
#  '광희 방탄 대신 군대 만 더 오자 애국',
#  '괜시리 눈물 난 보고 사랑 이 볼 수 날 기도',
#  '음악 보답',
#  '박명수 그 자리 꿰찬다',
#  '척 지구 요 팬 선비 코스프레',
#  '이혼 게 성 거',
#  '괸찬 갑상선암 치료 걱정 안 해도 완쾌 다시 무대 서기 화이팅',
#  '교통사고 피해자 합의 형사 처벌 안 게 노엘 합의금 후 합의 성사 원만 거 왜',
#  '놈 황구라',
#  '구구단 배우자 돈 안 손 절하 게 김세정 구구단 감옥 탈출',
#  '절절 말 자꾸 시비 걸 고 불만 사람 범죄자 정준영 지인',
#  '매 인물 좀 별로 고 설정 자체 좀 거지 요 항상 표정 위협',
#  '매 출연 순간 안 재수',
#  '구두 뭐 살 수술 겟',
#  '구라 라다 기레',
#  '뭔가',
#  '구미호 때 연기 정말',
#  '구씨 덕 것 안 결과 때',
#  '짱',
#  '구찌 화보 촬영 중 억',
#  '구하라 나이 정도 어차피 임신 걱정 안 해도',
#  '구하라 남친 피해자 옌 얼굴 하나 꼬셔놓',
#  '구하라 벌금 전남 친 징역 개월 집행유예 성폭력 예방 교육 이수 끝',
#  '구하라',
#  '구하라 온몸 멍 하혈 데 최종범 상해죄 적용 안 왜 구하라 상해죄 해당 네',
#  '구하라 응원 머리',
#  '구하라 팬 죠깥 네 남자 새끼',
#  '구혜선 동안 안재현 마녀사냥 거 군',
#  '구혜선 젖꼭지 실망',
#  '구혜선 안재현 사랑 꼭지 게',
#  '구혜선 게 부부 고 결혼 생활 좀 보고',
#  '구혜선 마음 남자',
#  '구혜선 화이팅',
#  '구혜선 화이팅 꽃길',
#  '구혜선',
#  '구혜선 응원 변심 안 재현 식 죗값 여배우 여자 인생 놈',
#  '구혜선 뱀 구차 얍 삽 년 바짓가랑이 방법 차암',
#  '구혜선 학업 형태 로 활동 재능 사람 쓰레기 늘 응원',
#  '구혜선 추잡 이 뭐 짓 남편 생매장 다음 데리 살 거 너 죽 고 나 심 뽀 여론몰이 니 게 뭐 침',
#  '구혜선 본인 활동 안 재현 본인 게 게 소속사 뒤 드라마 피해 거 사람',
#  '구혜선 씨 이 혼 안 재현 연예계 은퇴',
#  '구혜선 씨 새 미리 양해 구 지누 보기 성격 보이드 완전 가식 봄 거 성질 거',
#  '구혜선 씨 응원 소속사 댓글 알바 절대 것 천벌 거',
#  '구혜선 씨 항상 응원 지금 애기 시구 당신',
#  '구혜선 내 향 거 용인 안 재현 주민 술 데 성격 진짜 안 듯',
#  '구혜선 인스타 글 준비 기사 댓글 순식간 달리 분 저 연예 소속사 비리 국민 청원 이 상',
#  '구혜선 제일 악플러 선처 안 재현',
#  '국 의원 제발 일 좀 해 당 정치 색 달라 의견 충돌 건 이해 재정 법안 좀 통과 좀',
#  '국내 관종 환자 볼 수 프로',
#  '국내 일간 위 하나 그',
#  '국립공원 난입 난장 불지 피고 촬영 건 태국 정법 쟤 원래 문제 태국 당국 네 돈 주니 국립공원 고 뭐 덥석 손님 남 탓',
#  '국민 엠씨 가즈',
#  '국민 대다수 김미화 진행 능력 감탄 데 여기 비판 댓글 블랙리스트 옹호 충',
#  '국민 당신 용서 자숙 재 충전 작품',
#  '국민 개돼지 알 싸이 실망 꼭 강행 이유 직접',
#  '국방 의 무',
#  '국뽕 오지 사실 말 왜 난리',
#  '국 주씨 활동 듯 활동 이 뻐 화이팅',
#  '국주 언니 능력 천상여자 키크 고 돈 남자 꼭 능력 것 니 사람 못 거울 좀',
#  '군대',
#  '군대 짓',
#  '군대 안 발치 몽 인성 확인 응 손절',
#  '군대 게 눈물 나 거도 럿',
#  '군대 가라 우리 연결',
#  '군대 가라 검머 외 우리나라 검머 외도 금 환향 말',
#  '군대 가세',
#  '군대 가세 병역기피 꿈',
#  '군대',
#  '군대 가야 유아인 살 안',
#  '군대 안 미국인 한국 돈 버 거 여 얼탱',
#  '군대 가야',
#  '군대 생활 기계',
#  '군대 안 고 뺑기 것 갇 디',
#  '군대 의 무병 기 타 목격담 이미지 진짜 포장 얘 포장 애도',
#  '군 복무 중인 규현 대타 군대 안 온 놈 김희철',
#  '군 복무 중 거 금수 저 연예인 거',
#  '군복 적폐 문재인 인민 복 인공 달 쭉쭉',
#  '굳이 기사 심리 뭘',
#  '굳이 이 시점',
#  '갑툭',
#  '건 기레기 뿐 어디 수작',
#  '인스타 구경 영상 여자 임 전',
#  '궁합',
#  '궂 안 안',
#  '권력 범죄자 너 아방궁 대북 송금 영부인 꽤 거 끼리끼리 해묵 건 사실 도둑 제발 린다 더니 해',
#  '권리 말',
#  '권상우 김희원 이름 희한 놈 거 인상 미생 살인 충 데',
#  '권태기 온 거 단물 쪽 빨 듯 주위 여 자가 거지 임 문제 남자 여자 거',
#  '권태기 이 혼 수십 번 이 혼 남편 구혜선 씨',
#  '커플',
#  '규현 이제',
#  '그 가격 팔면 뭐 장사 고',
#  '그 나이 굳이',
#  '그 나이 임신',
#  '그 놈 새끼 얘 정상 정신 게 젖꼭지 차라리 가슴 좀 더 성적 이 제 고마 관종',
#  '그 맘 심정 저 강쥐 안락사 하늘나라 보 내 우울증 인연 다른 강쥐 데리',
#  '그 밥 그 나물 끼리끼리',
#  '그 신세경 예능 몰카 사건 방송국 놈 덜 놈 지구',
#  '그 여자 완전 또 라이네 또 라이 잘못 건 고생',
#  '그 여자도 인생 고통 전 라지 내 욕구 잠시 행동 반성 다시',
#  '그 와중 인스타 연예인 답',
#  '그 임신 개념 뇬 때문',
#  '그 종족 분',
#  '그 시간 팬 위해 앞 보고 거 알 강 다니엘 걱정 마 우리 그대로 무대 얼른 보고 얼른 무대 강 다니엘 답',
#  '갑자기 이 듣보잡 게 꼴 보기',
#  '햇',
#  '기 시화 것 웃기',
#  '거 말 거 이해 안 함',
#  '그것 양인 입장 저 얼굴 게 충격 일 듯',
#  '그게 뭐 때 현아 성격 여자 건 성질 계집 년 차원 다른 여신',
#  '그게 게 왜 데 열 니 회사 대표 약 문제 개 니 회사 연습생 말 관심',
#  '볼 만 드라마 이 제 네 모든 배우 고생',
#  '블랙',
#  '옷 소품 치장 촌 상',
#  '이미지 사람 황수정',
#  '그 나이 안 게 거지',
#  '그 나이',
#  '김태희 집안 결혼 거',
#  '장동건 고소영 딸 여 자연 예인 오징어',
#  '김충재 연예인',
#  '그냥',
#  '그냥 가요 무대 제적',
#  '그냥 강남 상판',
#  '그냥 강 비 행동 정 네 상대방 생각 안 반 말 사이 얼마나 누가 거짓말 유튜브 강 비 동영상 보고 내',
#  '그냥 결혼 기사',
#  '그냥 계속',
#  '그냥 고음 싱어 고음 사람 프로',
#  '그냥 기 내용 보기 가희 쁘네 얼굴',
#  '그냥 꼴 보기',
#  '그냥 노래',
#  '그냥 노이즈 마케팅 거인 듯',
#  '그냥 둘 맘 듯 홍진영 등치 리더십 상남자 스탈 김종국 애교 여자 듯',
#  '그냥 무작정 성년 자도 결혼 수 나이 처 애 우려 너희 훨 지금 비방 댓글 부모님 등골 것 거 인생 늘 불만',
#  '그냥 사람',
#  '그냥 상 손태영 권상우 손태영 상한 체 상 그냥 일상 왜 봉사 거나 좀 리지 기부 살기 상 더 함',
#  '그냥 번 개탄 사서 마무리',
#  '그냥 보통 듯',
#  '그냥 당신 작가 작가 사람 작가 의중 그냥 단지 드라마 일 뿐 현실 착각 작가 갑',
#  '그냥 사 귀어',
#  '그냥 성매매 양지 바 암암리 거',
#  '그냥 속 영화 관계자 강 비 쪽 삼자 해 그게 훨 이 뭐 둘 일이 둘 꼭 여기 왜 네티즌 네일',
#  '그냥 쓰레기 너 여자 그냥 성 노리개',
#  '그냥 안 거 데',
#  '그냥 어디 섬 하나 사서 공산주의 틀니 쉰 내',
#  '그냥 여자 음탕 할애비 그 이상 그 이하',
#  '그냥 예능 좀',
#  '그냥 옥주현',
#  '그냥 운동 거 허벅지 보기',
#  '그냥 응원',
#  '그냥 이상 바이 나인 데뷔 답',
#  '그냥 이 모 아줌마 벙',
#  '그냥 이 뻐 이 뻐 매력',
#  '그냥 이 혼 인생 인연 걸 분해 자신 위해',
#  '그냥 자',
#  '그냥 개그맨 생각 머리 당황',
#  '그냥',
#  '그냥 전라도 사람 듯 저 발언 부산 생각 그냥',
#  '그냥 좀 푹 쭉',
#  '그냥 좀 살 안 설정 네 어쩌 네 전 애 하나 잡지 네나 억지 설정 제대로 라이프 생활 혼자 등산 하든 서점 가든 남 평가 시간 자신 제 발',
#  '그냥 좀 만 입자',
#  '그냥 폐지 프로그램 해 관찰 예능 벌써 섭외 범죄자 연결 사람 굳이 섭외 이 유가 뭐 임 작가 진 반성 대충 대충',
#  '그냥 무슨 발표',
#  '그냥 하차 것 그간 통 속 시청자 우롱 연기자 자기 잘못 하나 식 한쪽 책임 다른 출연자 소금 짓 진 기적 게 이 부부 기적 듯',
#  '그냥 하차',
#  '그냥 한국 여자 거르셈 난 이 손절함',
#  '그냥 한번 끝내',
#  '그냥 해도 황 하나 물든 거지 박유천 좀 본질 승리 마약 정경 유착 정부',
#  '그냥 헬쥐팀 처럼 이 년도 곳 저 넘 차이 날 맥주 차마 시 헬쥐 팬 유광 점퍼',
#  '그냥 거 정도',
#  '그냥 대지 솔 반짝 글 옛날 노래 다시 거 반칙 다른 가수 리 메이크 것 커버 곡 왜 난 린지',
#  '그냥 연예인 모라 티 비 하니',
#  '그녀 그룹 바 방탄 발바닥',
#  '그녀',
#  '놈 버닝 문제',
#  '박 환희 이 여자 뭐 여자 구',
#  '선예 책임감 기적 행동 거지 그때 기사 자기 땐 컴 백 준비 비난 팀 본인 때 메 해체 상황 이면',
#  '여관 왜 모텔 내 썸녀 전 애 나 고발',
#  '남편 마약 일 거 라이',
#  '그니 혼 외 자식 왜 거 시기 내 씨 뿌리 것 니 업 죽 때 고생 좀 하겄',
#  '그다지 애 땜',
#  '그대 사랑 명곡',
#  '그동안 애 감성 얼마나 국민 앞 낱낱이 공개 검찰 문제 특검 실시 그 아내 정원',
#  '그 속 중국인 사실 그 기자 돈 중국 환영 허상',
#  '그 소리 쯤 때 말 당신 헛 소리 때문 상처',
#  '그때 축하 물 머',
#  '그때 실제 때 일',
#  '이 뻐 부러',
#  '그동안 꼽 치료 전념 꼭 완쾌',
#  '민폐 키 난쟁이 똥 자루 게 안 사이',
#  '반성',
#  '유서 디어 클라우드 나인 대중 걸 너희',
#  '연기 예능 생명 유지',
#  '죗값 치루 다시 방송',
#  '학원 선생 해 후배 연재 선생 뎅 도 보고 일석이조 뎅 후배 애 더 뎅 보고 더',
#  '한번 인생 여자 평생 건 남자 한텐',
#  '난 너 별 루 얏호',
#  '나라 겄',
#  '구하라 눕힌 너 승자',
#  '국제 평창올림픽 가수 엑소',
#  '김용진',
#  '꽤',
#  '끝 발뺌 안 시 인 하니 다른 쓰레기 낫',
#  '난',
#  '난 파격 김현주',
#  '남 건 결혼 애도 보고',
#  '남자 로서 항상 인기 듯',
#  '너 죄책감 줄 송혜교 측은 뻔 탈세 고',
#  '거 차라리 게 낫 오늘 다이어트 빠샷',
#  '사생활 본인 노력 돈 사신 듯',
#  '사진 보 반성 거 보기',
#  '시랭 살 수도',
#  '애 입장 사진 자연 사진',
#  '외모 끼 다른 분야 활약 수 거임 중반 한창',
#  '욕 니 재료 위생 음식점 얼마나 차라리 맛 게 낫',
#  '유혹 포상 휴가 가야',
#  '이 번 시즌 바다 창자 다행 요 예전 창 가창 중점 의 외 우승자',
#  '이번 동생 데 저번 머리 게 위생',
#  '인정 모습',
#  '자비 더 거 설현',
#  '조금 쉬 이해해 주 것 한국 외모 지장 주의 나라 다행 다행 복귀 기념 콘서트 성황리 매진 함 세용',
#  '저 정도 양호 거 요',
#  '진 결정 프로그램 만들기 위해 투입 직원 일자리 다른 작품 생각 다시 바 요',
#  '진심',
#  '초희',
#  '혜빈 그동안 다행 네',
#  '모자이크 처리 걸 생명 은인',
#  '사 엔딩 엑소 레전드 엑소',
#  '봣 밤일 잘해야 살',
#  '아이유 밑',
#  '언제 해',
#  '군대 언제 입대 하나요',
#  '사람 구 그랫구 지랄 움 그랫구',
#  '',
#  '남자 연예인',
#  '누드 거 넹',
#  '방탄 군대 가야',
#  '승리 청와대 연결고리 통 수사 진행 안 북한 대한민국',
#  '왜',
#  '이 와중 별 욕 게 역시 나라',
#  '정겨운 이 혼 사유 아웃 겨 녀',
#  '개 왜 무릎 짓 결혼 사이 왜 짓 함',
#  '거미 조정석 거미줄',
#  '애 데리 티비 좀 마 애기 때 프로 애기 침대 툭 리포터 깜짝 애기 해도 해',
#  '보고 결혼',
#  '개그맨 개그우먼 결혼 또 오랬 동안 트러블',
#  '일상 자발 일일이 보고 결식 무슨 유난 비공개',
#  '차태현 네 소속사 배우 안 일로 거 처음 거',
#  '살찐 거 컴플 개솔찍찍 살 여자 키 거 머리 거 노력 도 게 진짜 컴플',
#  '표정 관리 좀',
#  '맙시 신인 본인 오죽 하차',
#  '범죄자 살인 미수 음주운전 살인 미수 예 요 반성 따위 글 젠 악플 때문 면서 실수 쯧쯧 누굴 나나 요 다른 노처녀 양보',
#  '이 일인 너희 악플러 항상 먹잇감 난 오히려 백종원 그 여자 계속 화 게 이 상 이 여자 컨셉 고 대본',
#  '군 복무 중 음원 발표 자 작곡 수록 음원 수익 발생 군인 신분 영리활동 해도 것 궁금',
#  '승리',
#  '이 사람 누구 기사',
#  '회사 아빠 회사',
#  '이야기 수도 실제 것 별 거 랄 넹',
#  '수도 이 게 논란 홍 목소리 더',
#  '줄 군대 거 가기 전 거 어차피 훈련소 계산 거지 뭐 누가 국 금메달 리스트 줄',
#  '남편 포주 인 건가',
#  '머 아이 난 팬 볼 때 자기 주관 머 머 그냥 뿐',
#  '문재인 하나',
#  '보검',
#  '서현진 서브 이 백진희 주인공 어그',
#  '시즌 멤버 전원 정해 데뷔 애 문제 거',
#  '우유 적임 생각 사람 이 상한 거',
#  '이 성미 미혼',
#  '정용화 사과',
#  '최종범 사형 음주운전 협박 폭력 가택 침입 리벤지 포르노 전부 해당 사형 남자 거지',
#  '티켓 반값 프로 할인',
#  '한국 재난 때 중국 연예인 한국 응원 안 더구나 송혜교 중국 활동 데',
#  '분 방송 게',
#  '방송 물 카메라 마사지 얼굴 몸매 인정',
#  '일본 불매 사람 역시 개 돼지',
#  '죄 사생활 침해',
#  '네 여 혐 사실',
#  '스승 어디 서나',
#  '백종원 니 한계 이제 니 수준 인스턴트 레시피 방송 욕심 거품 인지도 본래 니 본업 가맹 점주',
#  '연예인 피해자 거부권 때문 컴백 수',
#  '달 수형 좀 불쌍',
#  '가면 먼저 간 사람 퍽',
#  '사실 대체 그 캐리 분배 안 뭐 노스 최강 거 스포 저 기대 보 안 것',
#  '리얼 하니 중간 관 거지 커플 몇 경우 여자 상처 안 노총각 좀 어차피 여자 자기 홍보 그 이상 이',
#  '비키니 건 가슴 좀 엄마 비키니 못 게 가슴 골 아이 앞 반 이상 건 듯 아이 나중 사진 볼',
#  '남자 직업 거짓말 말 해 신라 호텔 게 스몰 웨딩 돈 거기 하나',
#  '소유진 존 나 관 종인 듯 꼴 보기 나 대고 존 나 안 제발 그',
#  '나 랄 풍년',
#  '나와라',
#  '욕 스스로 벌',
#  '좀 기 사 알',
#  '좀 악플러 새끼',
#  '좀 나와라 김종국',
#  '좀 서로 굼 이해 노력',
#  '좀 해 이제',
#  '좀 해 겹 아예 남자 구멍 끼리 게 듯',
#  '줄 알 우리 아이 걱정 요',
#  '그 방송 만큼 것',
#  '그 좀 해 개 나소 미투 하넼 계 남자 등 거 줄 거',
#  '좀 후배 그 돈 가지',
#  '좀',
#  '좀 성은 씨 활동 좀',
#  '좀비 꼽시 딸 대세 그냥 수 말 디 왜 그냥 축복',
#  '좀 해 사람 죽 겄 기자 기사 내 사람 하나 나가야 건가 벌 거 알 권리 이 충족 더 이상 알',
#  '가족 애 간장 죽 땐 가야',
#  '탁제훈 신뢰 수 매력 사람',
#  '쟤 이상윤 입 개빡',
#  '후',
#  '분과 일만 배우 이미지 도움 게 하나 듯 여 동료 배우 거기',
#  '그 남 피 것 본인 맙시',
#  '그 빛 엠마 때 힐 거일 듯',
#  '그 사람 자식 당한 사람 실명 이름 공개 가족 모두 고사 꼴',
#  '그 시간 이 제 무얼 시즌 로 주시 정말 기 릴 요',
#  '그 알 특징 내용 거 수준 의혹 남발 함',
#  '그 알 남 진짜 일 꼬 러브 김상중 너 한남 소리 듣기 똑바로 해',
#  '그 알 번 꼴',
#  '그 애 그 딸 그 남편',
#  '그 와중 박수홍 언급 코디 고인 명복',
#  '그 와중 조보아',
#  '그 와중 지성 유니클로 광고 점',
#  '그 입 지금 골목 시장 짜장면 집 빽 다방 등 철수 돈 돈 욕심',
#  '은 퇴각',
#  '쪽 지역 출신 뭐',
#  '중 역할 찰떡 듯 다음 볼 의 향',
#  '중 정 경호 아빠 해리포터 론 스캐 버스 피터',
#  '중 지성 역할 정말 별로',
#  '근대 불법 거 방송 내 이슈 음 머',
#  '근대 와중 박나래 건 진짜 재는 티비 안 눈 걸 진심 느낌 진심 여 이건 악플 내 주변 남자 박나래 이국주 채널 돌림',
#  '근대 저 조폭 최소 조폭 경험 거 생겻 던데 학창시절 괴롭힘 당한 사람 거',
#  '문자 공개 거 그 이후 짓 게 전 카톡 협박 거',
#  '살 도 유모차 애가 초 출생 걸 살이 유모차 지나',
#  '왕 배치 급',
#  '이번 기회 빅뱅 듯 힘 그동안 거 듯 함',
#  '곽선영 모성애 자극 연기 목소리 아나운서 난 미나 제일 미나 바람 수 게 안 아주 용 해주 곽선영 럭셔리 굿',
#  '구하라 여자 욕 거 남자 구하라 무조건 구하라 편',
#  '군인 이후 외출 불가능 군 법',
#  '이 혼하 시 부모 장인 장모 길 관계 서로 호칭',
#  '김성주 아기 입맛 평소 강조 청국장 전문가 아기 입맛 청국장 매핑 안 거',
#  '김은숙 작가 작품 항상 후반',
#  '김지석 짬밥',
#  '난 서장훈 낯빛 어 두운 게 간이 안 사람 보이 데 검사 번',
#  '김수현 말투 느낌 목소리 말투',
#  '누구',
#  '누구 요',
#  '댓글 애교 데 기분 투',
#  '델루 특집 왜 거임 존심 스카이 캐슬 때 얘넨 타 방송국 프로 왜 자꾸 빨대',
#  '도대체 누구 연예인 아무나 기사 막',
#  '멤버 매니저 집 수도 건 강성훈 사과',
#  '무대 스크린 문구 산이 일일이 컨펌',
#  '민아 노래 누가',
#  '박보검 드라마 도저히 못',
#  '방탄 강 다니엘 사람 건 사실',
#  '백 선생님 왜 고함 시 청율 진 계속 편집 거 번 듣기 때 의도',
#  '백종원 씨 스타일 재 스타일 함 요즘 허세 경우 사장 인 격 문제 마카롱 집도 장사 이 뿌기 해도 정도 상임',
#  '범죄 것 문제 잠자리 호색 왜 문제',
#  '변기 유천 빠들 왜 관련 도 이세영 기사 쿵쾅 거임 퇴물',
#  '알바 데',
#  '브라 적도 한남 왜 더 거품 물 난리 임 관심 기사 댓글 비율 한국 남성 임 브라 적도 수컷 주제',
#  '사진 선 거부 감',
#  '세금',
#  ...]

# %%
from sklearn.linear_model            import LogisticRegression
from sklearn.model_selection         import GridSearchCV, train_test_split, cross_val_score
from sklearn.metrics                 import accuracy_score, recall_score, roc_auc_score, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag                      import Okt; t=Okt()

# %%
def t_tokenizer(text):
    tokens_ko = t.morphs(text)
    return tokens_ko

# %%
X_train = train['comments']
X_test = test['comments']
y_train = train['label']
y_test = test['label']

# 벡터라이저 생성
tfidf_vect = TfidfVectorizer(tokenizer=t_tokenizer, ngram_range=(1,2), min_df=3, max_df=0.9)

# 벡터라이저 학습
tfidf_vect.fit(X_train)

# 벡터라이저 리턴
tfidf_matrix_train = tfidf_vect.transform(X_train)

# 로지스틱 리그레션 학습
lr = LogisticRegression(solver='liblinear', random_state=13)
lr.fit(tfidf_matrix_train, y_train)

# 로지스틱 리그레션 예측
tfidf_matrix_test = tfidf_vect.transform(X_test)
preds = lr.predict(tfidf_matrix_test)
accuracy_score(y_test, preds), f1_score(y_test, preds, average='macro')
# Out:
# /Users/jaecheolchoi/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:484: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# (0.5796178343949044, 0.5680260820583809)

# %%
test['label'] = preds
test.head()
# Out:
#                                        comments      label
# 0  ㅋㅋㅋㅋ 그래도 조아해주는 팬들 많아서 좋겠다 ㅠㅠ 니들은 온유가 안만져줌 ㅠㅠ       none
# 1                                 둘다 넘 좋다~행복하세요       none
# 2          근데 만원이하는 현금결제만 하라고 써놓은집 우리나라에 엄청 많은데       none
# 3         원곡생각하나도 안나고 러블리즈 신곡나온줄!!! 너무 예쁘게 잘봤어요       none
# 4                            장현승 얘도 참 이젠 짠하다...  offensive

# %%
test['label'][test['label'] == 'none'] = 0

# %%
def kaggle_format(df):
    df['label'][df['label'] == 'none'] = 0
    df['label'][df['label'] == 'offensive'] = 1
    df['label'][df['label'] == 'hate'] = 2
    return df

# %%
kaggle_format(test)
# Out:
#                                               comments label
# 0         ㅋㅋㅋㅋ 그래도 조아해주는 팬들 많아서 좋겠다 ㅠㅠ 니들은 온유가 안만져줌 ㅠㅠ     0
# 1                                        둘다 넘 좋다~행복하세요     0
# 2                 근데 만원이하는 현금결제만 하라고 써놓은집 우리나라에 엄청 많은데     0
# 3                원곡생각하나도 안나고 러블리즈 신곡나온줄!!! 너무 예쁘게 잘봤어요     0
# 4                                   장현승 얘도 참 이젠 짠하다...     1
# ..                                                 ...   ...
# 969                     대박 게스트... 꼭 봐야징~ 컨셉이 바뀌니깐 재미지넹     0
# 970  성형으로 다 뜯어고쳐놓고 예쁜척. 성형 전 니 얼굴 다 알고있다. 순자처럼 된장냄새...     1
# 971  분위기는 비슷하다만 전혀다른 전개던데 무슨ㅋㅋㄱ 우리나라사람들은 분위기만 비슷하면 ...     0
# 972                               입에 손가릭이 10개 있으니 징그럽다     2
# 973                              난 조보아 이뻐서 보는데 백종원 관심무     0
#
# [974 rows x 2 columns]

# %%
test.head()
# Out:
#                                        comments label
# 0  ㅋㅋㅋㅋ 그래도 조아해주는 팬들 많아서 좋겠다 ㅠㅠ 니들은 온유가 안만져줌 ㅠㅠ     0
# 1                                 둘다 넘 좋다~행복하세요     0
# 2          근데 만원이하는 현금결제만 하라고 써놓은집 우리나라에 엄청 많은데     0
# 3         원곡생각하나도 안나고 러블리즈 신곡나온줄!!! 너무 예쁘게 잘봤어요     0
# 4                            장현승 얘도 참 이젠 짠하다...     1

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   comments  974 non-null    object
#  1   label     974 non-null    object
# dtypes: object(2)
# memory usage: 15.3+ KB

# %%
test.to_csv('./0109_jc.csv', index=False)

# %%
pd.read_csv('./0109_jc.csv')
# Out:
#                                               comments  label
# 0         ㅋㅋㅋㅋ 그래도 조아해주는 팬들 많아서 좋겠다 ㅠㅠ 니들은 온유가 안만져줌 ㅠㅠ      0
# 1                                        둘다 넘 좋다~행복하세요      0
# 2                 근데 만원이하는 현금결제만 하라고 써놓은집 우리나라에 엄청 많은데      0
# 3                원곡생각하나도 안나고 러블리즈 신곡나온줄!!! 너무 예쁘게 잘봤어요      0
# 4                                   장현승 얘도 참 이젠 짠하다...      1
# ..                                                 ...    ...
# 969                     대박 게스트... 꼭 봐야징~ 컨셉이 바뀌니깐 재미지넹      0
# 970  성형으로 다 뜯어고쳐놓고 예쁜척. 성형 전 니 얼굴 다 알고있다. 순자처럼 된장냄새...      1
# 971  분위기는 비슷하다만 전혀다른 전개던데 무슨ㅋㅋㄱ 우리나라사람들은 분위기만 비슷하면 ...      0
# 972                               입에 손가릭이 10개 있으니 징그럽다      2
# 973                              난 조보아 이뻐서 보는데 백종원 관심무      0
#
# [974 rows x 2 columns]
